# %%
import pandas as pd

# %%
df = pd.read_csv("student-dataset.csv")
df
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df  = pd.read_csv("student-dataset.csv", usecols = ["name", "city"])      # filtering
df
# Out:
#                   name                 city
# 0            Kiana Lor               Suzhou
# 1       Joshua Lonaker        Santa Clarita
# 2        Dakota Blanco              Oakland
# 3      Natasha Yarusso        Castro Valley
# 4       Brooke Cazares  São José dos Campos
# ..                 ...                  ...
# 302        Austin Haas             Columbus
# 303    Madison Fithian          Los Angeles
# 304  Zachary Mulvahill          Los Angeles
# 305   Eliana Michelsen              Oakland
# 306    Dane Whittemore              Toronto
#
# [307 rows x 2 columns]

# %%
df = pd.read_csv("student-dataset.csv")
df
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df.head(4)
# Out:
#    id             name               nationality           city  latitude  \
# 0   0        Kiana Lor                     China         Suzhou     31.31
# 1   1   Joshua Lonaker  United States of America  Santa Clarita     34.39
# 2   2    Dakota Blanco  United States of America        Oakland     37.80
# 3   3  Natasha Yarusso  United States of America  Castro Valley     37.69
#
#    longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     120.62      F           NaN   22            3.5         3.7
# 1    -118.54      M           NaN   22            2.9         3.2
# 2    -122.27      F           NaN   22            3.9         3.8
# 3    -122.09      F           NaN   20            3.3         2.8
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# ...

# %%
df.tail(4)
# Out:
#       id               name               nationality         city  latitude  \
# 303  303    Madison Fithian  United States of America  Los Angeles     34.05
# 304  304  Zachary Mulvahill  United States of America  Los Angeles     34.05
# 305  305   Eliana Michelsen  United States of America      Oakland     37.80
# 306  306    Dane Whittemore                    Canada      Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 303    -118.24      F           NaN   20            3.6         3.9
# 304    -118.24      M           NaN   20            3.2         3.4
# 305    -122.27      F           NaN   23            3.0         2.8
# 306     -79.42      M           NaN   21            3.8         3.2
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 303             4.0             5.0                 5                 5.0
# 304             3.9             5.0                 5                 5.0
# ...

# %%
df.shape
# Out:
# (307, 16)

# %%
df.size
# Out:
# 4912

# %%
df.values
# Out:
# array([[0, 'Kiana Lor', 'China', ..., 4, 4.0, 4],
#        [1, 'Joshua Lonaker', 'United States of America', ..., 5, 4.0, 5],
#        [2, 'Dakota Blanco', 'United States of America', ..., 3, 3.0, 4],
#        ...,
#        [304, 'Zachary Mulvahill', 'United States of America', ..., 5,
#         5.0, 3],
#        [305, 'Eliana Michelsen', 'United States of America', ..., 4, 4.0,
#         5],
#        [306, 'Dane Whittemore', 'Canada', ..., 5, 4.0, 5]],
#       shape=(307, 16), dtype=object)

# %%
df.memory_usage()
# Out:
# Index                  132
# id                    2456
# name                  2456
# nationality           2456
# city                  2456
# latitude              2456
# longitude             2456
# gender                2456
# ethnic.group          2456
# age                   2456
# english.grade         2456
# math.grade            2456
# sciences.grade        2456
# language.grade        2456
# portfolio.rating      2456
# coverletter.rating    2456
# refletter.rating      2456
# dtype: int64

# %%
df.T
# Out:
#                           0                         1    \
# id                          0                         1
# name                Kiana Lor            Joshua Lonaker
# nationality             China  United States of America
# city                   Suzhou             Santa Clarita
# latitude                31.31                     34.39
# longitude              120.62                   -118.54
# gender                      F                         M
# ethnic.group              NaN                       NaN
# age                        22                        22
# english.grade             3.5                       2.9
# math.grade                3.7                       3.2
# sciences.grade            3.1                       3.6
# language.grade            1.0                       5.0
# portfolio.rating            4                         5
# coverletter.rating        4.0                       4.0
# refletter.rating            4                         5
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=307, step=1)

# %%
df.isnull()
# Out:
#         id   name  nationality   city  latitude  longitude  gender  \
# 0    False  False        False  False     False      False   False
# 1    False  False        False  False     False      False   False
# 2    False  False        False  False     False      False   False
# 3    False  False        False  False     False      False   False
# 4    False  False        False  False     False      False   False
# ..     ...    ...          ...    ...       ...        ...     ...
# 302  False  False        False  False     False      False   False
# 303  False  False        False  False     False      False   False
# 304  False  False        False  False     False      False   False
# 305  False  False        False  False     False      False   False
# 306  False  False        False  False     False      False   False
#
#      ethnic.group    age  english.grade  math.grade  sciences.grade  \
# 0            True  False          False       False           False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  307 non-null    int64
#  1   name                307 non-null    object
#  2   nationality         307 non-null    object
#  3   city                307 non-null    object
#  4   latitude            307 non-null    float64
#  5   longitude           307 non-null    float64
#  6   gender              307 non-null    object
#  7   ethnic.group        0 non-null      float64
#  8   age                 307 non-null    int64
#  9   english.grade       307 non-null    float64
#  10  math.grade          307 non-null    float64
#  11  sciences.grade      307 non-null    float64
#  12  language.grade      307 non-null    float64
#  13  portfolio.rating    307 non-null    int64
#  14  coverletter.rating  307 non-null    float64
# ...

# %%
df.nunique()
# Out:
# id                    307
# name                  307
# nationality            31
# city                  161
# latitude              156
# longitude             158
# gender                  3
# ethnic.group            0
# age                     8
# english.grade          25
# math.grade             20
# sciences.grade         24
# language.grade          6
# portfolio.rating        5
# coverletter.rating      6
# refletter.rating        5
# dtype: int64

# %%
df.describe()
# Out:
#                id    latitude   longitude  ethnic.group         age  \
# count  307.000000  307.000000  307.000000           0.0  307.000000
# mean   153.000000   32.863388  -64.539121           NaN   21.964169
# std     88.767487   13.498582   81.249146           NaN    1.248013
# min      0.000000  -33.450000 -123.130000           NaN   19.000000
# 25%     76.500000   32.720000 -118.240000           NaN   21.000000
# 50%    153.000000   34.390000  -99.140000           NaN   22.000000
# 75%    229.500000   38.960000  -73.855000           NaN   23.000000
# max    306.000000   59.890000  139.750000           NaN   26.000000
#
#        english.grade  math.grade  sciences.grade  language.grade  \
# count     307.000000  307.000000      307.000000      307.000000
# mean        3.369707    3.414332        3.446580        4.396417
# std         0.538724    0.476839        0.509081        0.996474
# min         1.500000    2.100000        1.400000        1.000000
# ...

# %%
df["english.grade"].mean()
# Out:
# np.float64(3.3697068403908794)

# %%
df["math.grade"].std()
# Out:
# np.float64(0.47683919169989625)

# %%
df["sciences.grade"].median()
# Out:
# np.float64(3.6)

# %%
df["sciences.grade"].mode()
# Out:
# 0    3.9
# Name: sciences.grade, dtype: float64

# %%
x = df.loc[0, ["name" ,"city"]]
x
# Out:
# name    Kiana Lor
# city       Suzhou
# Name: 0, dtype: object

# %%
x = df.iloc[0,2]
x
# Out:
# 'China'

# %%
x = df.iloc[1,2]
x
# Out:
# 'United States of America'

# %%
data = {

    "Name": ["Atharv", "Akash", "Panda","Arjun"],
    "age": [21,23,34,100],
    "marks": [90,89,95,99]
    
}

y = pd.DataFrame(data)
y
# Out:
#      Name  age  marks
# 0  Atharv   21     90
# 1   Akash   23     89
# 2   Panda   34     95
# 3   Arjun  100     99

# %%
var = y.to_csv("demo.csv", index = False)
var

# %%
df = pd.read_csv("student-dataset.csv")
df
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 302    False
# 303    False
# 304    False
# 305    False
# 306    False
# Length: 307, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df.loc[0, "name"]
# Out:
# 'Kiana Lor'

# %%
df.loc[0,"name"] = "Atharv Salunke"

# %%
df
# Out:
#       id               name               nationality                 city  \
# 0      0     Atharv Salunke                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df.loc[4, "gender"]
# Out:
# 'F'

# %%
df.loc[4, "gender"] = "M"

# %%
df
# Out:
#       id               name               nationality                 city  \
# 0      0     Atharv Salunke                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df.to_csv("modified_csvfile.csv", index = False)
